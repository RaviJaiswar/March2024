# %%
from numpy import *
import os
import matplotlib.pyplot as plt
import astropy
import pandas as pd
from astropy.io import fits
from astropy.table import Table
from astropy.visualization import astropy_mpl_style
from astropy.utils.data import get_pkg_data_filename

plt.style.use(astropy_mpl_style)

path = os.path.expanduser('~/Desktop/BEAGLE_Filters/')
os.path.exists(path)
# Out:
# True

# %%
F435 = pd.read_csv(os.path.expanduser(path+'HST_ACS_WFC.F435W.dat'),header=None)
F606 = pd.read_csv(os.path.expanduser(path+'HST_ACS_WFC.F606W.dat'),header=None)
F775 = pd.read_csv(os.path.expanduser(path+'HST_ACS_WFC.F775W.dat'),header=None)
F814 = pd.read_csv(os.path.expanduser(path+'HST_ACS_WFC.F814W.dat'),header=None)
F850 = pd.read_csv(os.path.expanduser(path+'HST_ACS_WFC.F850LP.dat'),header=None)
F105 = pd.read_csv(os.path.expanduser(path+'HST_WFC3_IR.F105W.dat'),header=None)
F125 = pd.read_csv(os.path.expanduser(path+'HST_WFC3_IR.F125W.dat'),header=None)
F160 = pd.read_csv(os.path.expanduser(path+'HST_WFC3_IR.F160W.dat'),header=None)
F090 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F090W.dat'),header=None)
F115 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F115W.dat'),header=None)
F140 = pd.read_csv(os.path.expanduser(path+'HST_WFC3_IR.F140W.dat'),header=None)
F150 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F150W.dat'),header=None)
F182 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F182M.dat'),header=None)
F200 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F200W.dat'),header=None)
F210 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F210M.dat'),header=None)
F277 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F277W.dat'),header=None)
F335 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F335M.dat'),header=None)
F356 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F356W.dat'),header=None)
F410 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F410M.dat'),header=None)
F430 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F430M.dat'),header=None)
F444 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F444W.dat'),header=None)
F460 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F460M.dat'),header=None)
F480 = pd.read_csv(os.path.expanduser(path+'JWST_NIRCam.F480M.dat'),header=None)
F435
# Out:
#                             0
# 0      3526.000000 7.5973e-05
# 1      3527.000000 8.6502e-05
# 2     3528.000000 9.70997e-05
# 3     3529.000000 0.000107767
# 4     3530.000000 0.000118504
# ...                       ...
# 1449  4975.000000 0.000109642
# 1450  4976.000000 0.000101563
# 1451  4977.000000 9.34836e-05
# 1452  4978.000000 8.54017e-05
# 1453   4979.000000 7.7318e-05
#
# [1454 rows x 1 columns]

# %%
x = F435
x.loc[-1] = '# '+str(len(F435))+' HST/ACS_WFC_F435W.dat'
x.index = x.index + 1
x.sort_index(inplace=True) 
x

y = F606
y.loc[-1] = '# '+str(len(F606))+' HST/ACS_WFC_F606W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F775
y.loc[-1] = '# '+str(len(F775))+' HST/ACS_WFC_F775W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F814
y.loc[-1] = '# '+str(len(F814))+' HST/ACS_WFC_F814W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F850
y.loc[-1] = '# '+str(len(F850))+' HST/ACS_WFC_F850LP.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F090
y.loc[-1] = '# '+str(len(F090))+' JWST/NIRCam_F090W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F105
y.loc[-1] = '# '+str(len(F105))+' HST/WFC3_IR_F105W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F115
y.loc[-1] = '# '+str(len(F115))+' JWST/NIRCam_F115W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F125
y.loc[-1] = '# '+str(len(F125))+' HST/WFC3_IR_F125W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F140
y.loc[-1] = '# '+str(len(F140))+' HST/WFC_IR_F140W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F150
y.loc[-1] = '# '+str(len(F150))+' JWST/NIRCam_F150W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F160
y.loc[-1] = '# '+str(len(F160))+' HST/WFC3_IR_F160W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)


y = F182
y.loc[-1] = '# '+str(len(F182))+' JWST/NIRCam_F182M.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F200
y.loc[-1] = '# '+str(len(F200))+' JWST/NIRCam_F200W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F210
y.loc[-1] = '# '+str(len(F210))+' JWST/NIRCam_F210M.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F277
y.loc[-1] = '# '+str(len(F277))+' JWST/NIRCam_F277W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F335
y.loc[-1] = '# '+str(len(F335))+' JWST/NIRCam_F335M.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F356
y.loc[-1] = '# '+str(len(F356))+' JWST/NIRCam_F356W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F410
y.loc[-1] = '# '+str(len(F410))+' JWST/NIRCam_F410M.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F430
y.loc[-1] = '# '+str(len(F430))+' JWST/NIRCam_F430M.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F444
y.loc[-1] = '# '+str(len(F444))+' JWST/NIRCam_F444W.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F460
y.loc[-1] = '# '+str(len(F460))+' JWST/NIRCam_F460M.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)

y = F480
y.loc[-1] = '# '+str(len(F480))+' JWST/NIRCam_F480M.dat'
y.index = y.index + 1
y.sort_index(inplace=True) 
y

x = x.append(y)
x.to_csv('JADES_filters.dat',index=False,header=False)
x
# Out:
# /tmp/ipykernel_535648/870461229.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x = x.append(y)
# /tmp/ipykernel_535648/870461229.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x = x.append(y)
# /tmp/ipykernel_535648/870461229.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x = x.append(y)
# /tmp/ipykernel_535648/870461229.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x = x.append(y)
# /tmp/ipykernel_535648/870461229.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x = x.append(y)
# ...
